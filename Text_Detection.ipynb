# %% [markdown]
# # **OCR 모듈을 이용한 텍스트 객체 인식 및 추출**

# %%
# !pip install easyocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 57.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.2/619.2 KB 55.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.0/146.0 KB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 18.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.7.0.72
#     Uninstalling opencv-python-headless-4.7.0.72:
#       Successfully uninstalled opencv-python-headless-4.7.0.72
# ...

# %%
# load example images
# !npx degit JaidedAI/EasyOCR/examples -f
# Out:
# npx: installed 1 in 2.279s
# > destination directory is not empty. Using --force, continuing
# ^C

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("TEST12.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=754x426 at 0x7F40CC184700>

# %%
# Create a reader to do OCR.
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# WARNING:easyocr.easyocr:Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# WARNING:easyocr.easyocr:Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
# Doing OCR. Get bounding boxes.
bounds = reader.readtext('TEST12.png')
bounds
# Out:
# [([[605, 35], [641, 35], [641, 47], [605, 47]], 'DCIZV', 0.5374721018081391),
#  ([[396, 48], [428, 48], [428, 56], [396, 56]], 'DCI2U', 0.5159049498176758),
#  ([[195, 71], [229, 71], [229, 83], [195, 83]], 'DC1ZV', 0.3251164736803588),
#  ([[479, 99], [509, 99], [509, 111], [479, 111]], 'SOC1', 0.950956404209137),
#  ([[529, 99], [559, 99], [559, 111], [529, 111]], 'DRAI', 0.5115293264389038),
#  ([[339, 107], [389, 107], [389, 123], [339, 123]],
#   'GATE1)}',
#   0.6052257861018838),
#  ([[479, 109], [515, 109], [515, 123], [479, 123]],
#   'GATE1',
#   0.6160868593445911),
#  ([[523, 111], [555, 111], [555, 123], [523, 123]],
#   'DRAI',
#   0.5967287421226501),
#  ([[479, 121], [509, 121], [509, 133], [479, 133]], 'SOC2', 0.916131317615509),
#  ([[529, 121], [559, 121], [559, 133], [529, 133]],
#   'DRA2',
#   0.8648776412010193),
#  ([[26, 128], [94, 128], [94, 158], [26, 158]], '(PC7)', 0.8376102343009819),
#  ([[307, 129], [385, 129], [385, 145], [307, 145]],
# ...

# %%
# Draw bounding boxes
def draw_boxes(image, bounds, color='yellow', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bounds:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bounds)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=754x426 at 0x7F40CC184700>

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("TEST13.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=844x682 at 0x7F4012FA5F40>

# %%
# Create a reader to do OCR.
import easyocr
reader = easyocr.Reader(['en'])

# %%
# Doing OCR. Get bounding boxes.
bound1 = reader.readtext('TEST13.png')
bound1
# Out:
# [([[657, 7], [679, 7], [679, 19], [657, 19]], 'EX8', 0.4252875381009621),
#  ([[768, 8], [790, 8], [790, 16], [768, 16]], 'Vdd', 0.35116204619407654),
#  ([[269, 31], [291, 31], [291, 43], [269, 43]], 'VDD', 0.9831217160205036),
#  ([[641, 41], [655, 41], [655, 63], [641, 63]], '3', 0.37129387017422744),
#  ([[323, 73], [347, 73], [347, 87], [323, 87]], 'BUZ', 0.5026815533638),
#  ([[527, 79], [603, 79], [603, 93], [527, 93]],
#   '[1] 412_PWMO _',
#   0.4260539135497889),
#  ([[737, 79], [793, 79], [793, 91], [737, 91]],
#   '412_PWMO',
#   0.8611974219153964),
#  ([[553, 91], [601, 91], [601, 103], [553, 103]],
#   'A2_ADC2',
#   0.47510376718486197),
#  ([[737, 91], [785, 91], [785, 103], [737, 103]],
#   'A2_ADC2',
#   0.5633836032162264),
#  ([[543, 101], [601, 101], [601, 115], [543, 115]],
#   '[1]   SPLCS',
#   0.6843314941339856),
#  ([[737, 101], [777, 101], [777, 115], [737, 115]],
#   'SPL_CS',
#   0.4844736692270887),
# ...

# %%
# Draw bounding boxes
def draw_boxes(image, bound1, color='red', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bound1:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bound1)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=844x682 at 0x7F4012FA5F40>

# %%
# Create a reader to do OCR.
import easyocr
reader = easyocr.Reader(['en'])

# %%
# show an image
import PIL
from PIL import ImageDraw
im = PIL.Image.open("TEST14.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=859x477 at 0x7F4012FA5E20>

# %%
# Doing OCR. Get bounding boxes.
bound2 = reader.readtext('TEST14.png')
bound2
# Out:
# [([[380, 8], [436, 8], [436, 68], [380, 68]], 'MDH', 0.16085547902162267),
#  ([[397, 27], [421, 27], [421, 45], [397, 45]], '22', 0.9022151175779668),
#  ([[428, 10], [480, 10], [480, 68], [428, 68]], '8"3', 0.11477769608189937),
#  ([[453, 29], [465, 29], [465, 51], [453, 51]], '#', 0.13233083039594717),
#  ([[473, 11], [513, 11], [513, 51], [473, 51]], 'W', 0.13190002382221255),
#  ([[509, 13], [521, 13], [521, 75], [509, 75]], '1', 0.3206116193683215),
#  ([[396, 42], [432, 42], [432, 66], [396, 66]], '222', 0.574295377976642),
#  ([[471, 41], [513, 41], [513, 77], [471, 77]], '222', 0.26363714861137566),
#  ([[123, 91], [185, 91], [185, 107], [123, 107]],
#   '[2]  BUZZER',
#   0.9040436126969763),
#  ([[381, 95], [433, 95], [433, 107], [381, 107]],
#   'ADCSPAS',
#   0.5498478919226509),
#  ([[451, 93], [563, 93], [563, 107], [451, 107]],
#   'PCOISPISSWIZSLRCLK',
#   0.6283861496564546),
#  ([[139, 105], [153, 105], [153, 129], [139, 129]],
#   '128',
# ...

# %%
# Draw bounding boxes
def draw_boxes(image, bound2, color='green', width=2):
    draw = ImageDraw.Draw(image)
    for bound in bound2:
        p0, p1, p2, p3 = bound[0]
        draw.line([*p0, *p1, *p2, *p3, *p0], fill=color, width=width)
    return image

draw_boxes(im, bound2)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=859x477 at 0x7F4012FA5E20>

# %%
cd /content/drive/MyDrive/github
# Out:
# /content/drive/MyDrive/github

# %%
# !git clone https://cheonseunghyeon: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@github.com/cheonseunghyeon/Instrumentation-Drawing-Object-Detection.git
# Out:
# Cloning into 'Instrumentation-Drawing-Object-Detection'...
# ...

# %%
cd Instrumentation-Drawing-Object-Detection
# Out:
# /content/drive/MyDrive/github/Instrumentation-Drawing-Object-Detection

# %%
# !git config --global user.email 'kyr5191@gmail.com'
# !git config --global user.name 'cheonseunghyeon'

# %%
# !git add Line_Detection.ipynb
